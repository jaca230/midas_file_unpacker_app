# %%
import ROOT as r
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict
print(r.gROOT.GetVersion())
# Out:
# 6.36.04

# %%
import ROOT as r
import os

BUILD_LIB_PATH = "../../build/lib"

# Only load .so libraries in dependency order
libs_to_load = [
  "libanalysis_pipeline_core.so",
  "libunpacker_data_products_core.so",
  "libunpacker_data_products_nalu.so",
]

for lib in libs_to_load:
    path = os.path.join(BUILD_LIB_PATH, lib)
    if os.path.exists(path):
        print(f"Loading {path} ...")
        r.gSystem.Load(path)
    else:
        print(f"Skipping {path}, not found")
# Out:
# Loading ../../build/lib/libanalysis_pipeline_core.so ...
# Loading ../../build/lib/libunpacker_data_products_core.so ...
# Loading ../../build/lib/libunpacker_data_products_nalu.so ...

# %%
# Open file and get tree
DATA_FILE = "../../output.root"
f = r.TFile.Open(DATA_FILE)
tree = f.Get("events")

# %%
# For each channel, store a list of packet counts (per event)
channel_packet_counts = defaultdict(list)

# Loop over events
for event in tree:
    per_channel_counts = defaultdict(int)
    n_packets = len(event.nalu_event.packets.packets)  # number of packets in this event
    for i in range(n_packets):
        ch = int(event.nalu_event.packets.packets[i].channel)
        per_channel_counts[ch] += 1
    for ch, count in per_channel_counts.items():
        channel_packet_counts[ch].append(count)

# Now make histograms per channel
n_channels = len(channel_packet_counts)
fig, axes = plt.subplots(n_channels, 1, figsize=(6, 3*n_channels), sharex=True)

if n_channels == 1:
    axes = [axes]

for ax, (ch, counts) in zip(axes, sorted(channel_packet_counts.items())):
    ax.hist(counts, bins=range(1, max(counts)+2), edgecolor="black", align="left")
    ax.set_title(f"Channel {ch}: Packet count per event")
    ax.set_ylabel("Events")

axes[-1].set_xlabel("Packets per event")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# SegmentationViolation                     Traceback (most recent call last)
# Cell In[4], line 9
#       7 n_packets = len(event.nalu_event.packets.packets)  # number of packets in this event
#       8 for i in range(n_packets):
# ----> 9     ch = int(event.packets.packets[i].channel)
#      10     per_channel_counts[ch] += 1
#      11 for ch, count in per_channel_counts.items():
#
# File ~/miniconda3/envs/root_new/lib/python3.13/site-packages/ROOT/_pythonization/_ttree.py:308, in _TTree__getattr__(self, key)
#     306 out, cast_type = GetBranchAttr(self, key)
#     307 if cast_type:
# --> 308     out = cppyy.ll.cast[cast_type](out)
#     309 return out
#
# SegmentationViolation: Could not find "cppyy_cast<dataProducts::NaluPacketCollection*>" (set cppyy.set_debug() for C++ errors):
#   segfault in C++; program state was reset
#  *** Break *** segmentation violation
#
#
#
# ===========================================================
# There was a crash.
# This is the entire stack trace of all threads:
# ===========================================================
#
# Thread 24 (Thread 0x75540bfa5640 (LWP 129402) "python"):
# #0  __futex_abstimed_wait_common64 (private=0, cancel=true, abstime=0x0, op=393, expected=0, futex_word=0x7554735f1a60 <thread_status+1376>) at ./nptl/futex-internal.c:57
# #1  __futex_abstimed_wait_common (cancel=true, private=0, abstime=0x0, clockid=0, expected=0, futex_word=0x7554735f1a60 <thread_status+1376>) at ./nptl/futex-internal.c:87
# #2  __GI___futex_abstimed_wait_cancelable64 (futex_word=futex_word
# entry=0x7554735f1a60 <thread_status+1376>, expected=expected
# entry=0, clockid=clockid
# entry=0, abstime=abstime
# entry=0x0, private=private
# entry=0) at ./nptl/futex-internal.c:139
# #3  0x00007554c5693a41 in __pthread_cond_wait_common (abstime=0x0, clockid=0, mutex=0x7554735f1a10 <thread_status+1296>, cond=0x7554735f1a38 <thread_status+1336>) at ./nptl/pthread_cond_wait.c:503
# #4  ___pthread_cond_wait (cond=0x7554735f1a38 <thread_status+1336>, mutex=0x7554735f1a10 <thread_status+1296>) at ./nptl/pthread_cond_wait.c:627
# #5  0x00007554714b85ec in blas_thread_server () from /home/jack/miniconda3/envs/root_new/lib/python3.13/site-packages/numpy/_core/../../../../libcblas.so.3
# #6  0x00007554c5694ac3 in start_thread (arg=<optimized out>) at ./nptl/pthread_create.c:442
# #7  0x00007554c57268c0 in clone3 () at ../sysdeps/unix/sysv/linux/x86_64/clone3.S:81
#
# Thread 23 (Thread 0x75540c7a6640 (LWP 129401) "python"):
# #0  __futex_abstimed_wait_common64 (private=0, cancel=true, abstime=0x0, op=393, expected=0, futex_word=0x7554735f19e0 <thread_status+1248>) at ./nptl/futex-internal.c:57
# #1  __futex_abstimed_wait_common (cancel=true, private=0, abstime=0x0, clockid=0, expected=0, futex_word=0x7554735f19e0 <thread_status+1248>) at ./nptl/futex-internal.c:87
# #2  __GI___futex_abstimed_wait_cancelable64 (futex_word=futex_word
# entry=0x7554735f19e0 <thread_status+1248>, expected=expected
# entry=0, clockid=clockid
# entry=0, abstime=abstime
# entry=0x0, private=private
# entry=0) at ./nptl/futex-internal.c:139
# #3  0x00007554c5693a41 in __pthread_cond_wait_common (abstime=0x0, clockid=0, mutex=0x7554735f1990 <thread_status+1168>, cond=0x7554735f19b8 <thread_status+1208>) at ./nptl/pthread_cond_wait.c:503
# #4  ___pthread_cond_wait (cond=0x7554735f19b8 <thread_status+1208>, mutex=0x7554735f1990 <thread_status+1168>) at ./nptl/pthread_cond_wait.c:627
# #5  0x00007554714b85ec in blas_thread_server () from /home/jack/miniconda3/envs/root_new/lib/python3.13/site-packages/numpy/_core/../../../../libcblas.so.3
# #6  0x00007554c5694ac3 in start_thread (arg=<optimized out>) at ./nptl/pthread_create.c:442
# #7  0x00007554c57268c0 in clone3 () at ../sysdeps/unix/sysv/linux/x86_64/clone3.S:81
#
# Thread 22 (Thread 0x75540cfa7640 (LWP 129400) "python"):
# #0  __futex_abstimed_wait_common64 (private=0, cancel=true, abstime=0x0, op=393, expected=0, futex_word=0x7554735f1960 <thread_status+1120>) at ./nptl/futex-internal.c:57
# #1  __futex_abstimed_wait_common (cancel=true, private=0, abstime=0x0, clockid=0, expected=0, futex_word=0x7554735f1960 <thread_status+1120>) at ./nptl/futex-internal.c:87
# #2  __GI___futex_abstimed_wait_cancelable64 (futex_word=futex_word
# entry=0x7554735f1960 <thread_status+1120>, expected=expected
# entry=0, clockid=clockid
# entry=0, abstime=abstime
# entry=0x0, private=private
# entry=0) at ./nptl/futex-internal.c:139
# #3  0x00007554c5693a41 in __pthread_cond_wait_common (abstime=0x0, clockid=0, mutex=0x7554735f1910 <thread_status+1040>, cond=0x7554735f1938 <thread_status+1080>) at ./nptl/pthread_cond_wait.c:503
# #4  ___pthread_cond_wait (cond=0x7554735f1938 <thread_status+1080>, mutex=0x7554735f1910 <thread_status+1040>) at ./nptl/pthread_cond_wait.c:627
# #5  0x00007554714b85ec in blas_thread_server () from /home/jack/miniconda3/envs/root_new/lib/python3.13/site-packages/numpy/_core/../../../../libcblas.so.3
# #6  0x00007554c5694ac3 in start_thread (arg=<optimized out>) at ./nptl/pthread_create.c:442
# #7  0x00007554c57268c0 in clone3 () at ../sysdeps/unix/sysv/linux/x86_64/clone3.S:81
#
# Thread 21 (Thread 0x75540d7a8640 (LWP 129399) "python"):
# #0  __futex_abstimed_wait_common64 (private=0, cancel=true, abstime=0x0, op=393, expected=0, futex_word=0x7554735f18e0 <thread_status+992>) at ./nptl/futex-internal.c:57
# #1  __futex_abstimed_wait_common (cancel=true, private=0, abstime=0x0, clockid=0, expected=0, futex_word=0x7554735f18e0 <thread_status+992>) at ./nptl/futex-internal.c:87
# #2  __GI___futex_abstimed_wait_cancelable64 (futex_word=futex_word
# entry=0x7554735f18e0 <thread_status+992>, expected=expected
# entry=0, clockid=clockid
# entry=0, abstime=abstime
# entry=0x0, private=private
# entry=0) at ./nptl/futex-internal.c:139
# #3  0x00007554c5693a41 in __pthread_cond_wait_common (abstime=0x0, clockid=0, mutex=0x7554735f1890 <thread_status+912>, cond=0x7554735f18b8 <thread_status+952>) at ./nptl/pthread_cond_wait.c:503
# #4  ___pthread_cond_wait (cond=0x7554735f18b8 <thread_status+952>, mutex=0x7554735f1890 <thread_status+912>) at ./nptl/pthread_cond_wait.c:627
# #5  0x00007554714b85ec in blas_thread_server () from /home/jack/miniconda3/envs/root_new/lib/python3.13/site-packages/numpy/_core/../../../../libcblas.so.3
# #6  0x00007554c5694ac3 in start_thread (arg=<optimized out>) at ./nptl/pthread_create.c:442
# #7  0x00007554c57268c0 in clone3 () at ../sysdeps/unix/sysv/linux/x86_64/clone3.S:81
#
# Thread 20 (Thread 0x75540dfa9640 (LWP 129398) "python"):
# #0  __futex_abstimed_wait_common64 (private=0, cancel=true, abstime=0x0, op=393, expected=0, futex_word=0x7554735f1860 <thread_status+864>) at ./nptl/futex-internal.c:57
# #1  __futex_abstimed_wait_common (cancel=true, private=0, abstime=0x0, clockid=0, expected=0, futex_word=0x7554735f1860 <thread_status+864>) at ./nptl/futex-internal.c:87
# #2  __GI___futex_abstimed_wait_cancelable64 (futex_word=futex_word
# entry=0x7554735f1860 <thread_status+864>, expected=expected
# entry=0, clockid=clockid
# entry=0, abstime=abstime
# entry=0x0, private=private
# entry=0) at ./nptl/futex-internal.c:139
# #3  0x00007554c5693a41 in __pthread_cond_wait_common (abstime=0x0, clockid=0, mutex=0x7554735f1810 <thread_status+784>, cond=0x7554735f1838 <thread_status+824>) at ./nptl/pthread_cond_wait.c:503
# #4  ___pthread_cond_wait (cond=0x7554735f1838 <thread_status+824>, mutex=0x7554735f1810 <thread_status+784>) at ./nptl/pthread_cond_wait.c:627
# #5  0x00007554714b85ec in blas_thread_server () from /home/jack/miniconda3/envs/root_new/lib/python3.13/site-packages/numpy/_core/../../../../libcblas.so.3
# #6  0x00007554c5694ac3 in start_thread (arg=<optimized out>) at ./nptl/pthread_create.c:442
# #7  0x00007554c57268c0 in clone3 () at ../sysdeps/unix/sysv/linux/x86_64/clone3.S:81
#
# Thread 19 (Thread 0x75540e7aa640 (LWP 129397) "python"):
# #0  __futex_abstimed_wait_common64 (private=0, cancel=true, abstime=0x0, op=393, expected=0, futex_word=0x7554735f17e0 <thread_status+736>) at ./nptl/futex-internal.c:57
# #1  __futex_abstimed_wait_common (cancel=true, private=0, abstime=0x0, clockid=0, expected=0, futex_word=0x7554735f17e0 <thread_status+736>) at ./nptl/futex-internal.c:87
# #2  __GI___futex_abstimed_wait_cancelable64 (futex_word=futex_word
# entry=0x7554735f17e0 <thread_status+736>, expected=expected
# entry=0, clockid=clockid
# entry=0, abstime=abstime
# entry=0x0, private=private
# entry=0) at ./nptl/futex-internal.c:139
# #3  0x00007554c5693a41 in __pthread_cond_wait_common (abstime=0x0, clockid=0, mutex=0x7554735f1790 <thread_status+656>, cond=0x7554735f17b8 <thread_status+696>) at ./nptl/pthread_cond_wait.c:503
# #4  ___pthread_cond_wait (cond=0x7554735f17b8 <thread_status+696>, mutex=0x7554735f1790 <thread_status+656>) at ./nptl/pthread_cond_wait.c:627
# #5  0x00007554714b85ec in blas_thread_server () from /home/jack/miniconda3/envs/root_new/lib/python3.13/site-packages/numpy/_core/../../../../libcblas.so.3
# #6  0x00007554c5694ac3 in start_thread (arg=<optimized out>) at ./nptl/pthread_create.c:442
# #7  0x00007554c57268c0 in clone3 () at ../sysdeps/unix/sysv/linux/x86_64/clone3.S:81
#
# Thread 18 (Thread 0x75540efab640 (LWP 129396) "python"):
# #0  __futex_abstimed_wait_common64 (private=0, cancel=true, abstime=0x0, op=393, expected=0, futex_word=0x7554735f1760 <thread_status+608>) at ./nptl/futex-internal.c:57
# #1  __futex_abstimed_wait_common (cancel=true, private=0, abstime=0x0, clockid=0, expected=0, futex_word=0x7554735f1760 <thread_status+608>) at ./nptl/futex-internal.c:87
# #2  __GI___futex_abstimed_wait_cancelable64 (futex_word=futex_word
# entry=0x7554735f1760 <thread_status+608>, expected=expected
# entry=0, clockid=clockid
# entry=0, abstime=abstime
# entry=0x0, private=private
# entry=0) at ./nptl/futex-internal.c:139
# #3  0x00007554c5693a41 in __pthread_cond_wait_common (abstime=0x0, clockid=0, mutex=0x7554735f1710 <thread_status+528>, cond=0x7554735f1738 <thread_status+568>) at ./nptl/pthread_cond_wait.c:503
# #4  ___pthread_cond_wait (cond=0x7554735f1738 <thread_status+568>, mutex=0x7554735f1710 <thread_status+528>) at ./nptl/pthread_cond_wait.c:627
# #5  0x00007554714b85ec in blas_thread_server () from /home/jack/miniconda3/envs/root_new/lib/python3.13/site-packages/numpy/_core/../../../../libcblas.so.3
# #6  0x00007554c5694ac3 in start_thread (arg=<optimized out>) at ./nptl/pthread_create.c:442
# #7  0x00007554c57268c0 in clone3 () at ../sysdeps/unix/sysv/linux/x86_64/clone3.S:81
#
# Thread 17 (Thread 0x75540f7ac640 (LWP 129395) "python"):
# #0  __futex_abstimed_wait_common64 (private=0, cancel=true, abstime=0x0, op=393, expected=0, futex_word=0x7554735f16e0 <thread_status+480>) at ./nptl/futex-internal.c:57
# #1  __futex_abstimed_wait_common (cancel=true, private=0, abstime=0x0, clockid=0, expected=0, futex_word=0x7554735f16e0 <thread_status+480>) at ./nptl/futex-internal.c:87
# #2  __GI___futex_abstimed_wait_cancelable64 (futex_word=futex_word
# entry=0x7554735f16e0 <thread_status+480>, expected=expected
# entry=0, clockid=clockid
# entry=0, abstime=abstime
# entry=0x0, private=private
# entry=0) at ./nptl/futex-internal.c:139
# #3  0x00007554c5693a41 in __pthread_cond_wait_common (abstime=0x0, clockid=0, mutex=0x7554735f1690 <thread_status+400>, cond=0x7554735f16b8 <thread_status+440>) at ./nptl/pthread_cond_wait.c:503
# #4  ___pthread_cond_wait (cond=0x7554735f16b8 <thread_status+440>, mutex=0x7554735f1690 <thread_status+400>) at ./nptl/pthread_cond_wait.c:627
# #5  0x00007554714b85ec in blas_thread_server () from /home/jack/miniconda3/envs/root_new/lib/python3.13/site-packages/numpy/_core/../../../../libcblas.so.3
# #6  0x00007554c5694ac3 in start_thread (arg=<optimized out>) at ./nptl/pthread_create.c:442
# #7  0x00007554c57268c0 in clone3 () at ../sysdeps/unix/sysv/linux/x86_64/clone3.S:81
#
# Thread 16 (Thread 0x75540ffad640 (LWP 129394) "python"):
# #0  __futex_abstimed_wait_common64 (private=0, cancel=true, abstime=0x0, op=393, expected=0, futex_word=0x7554735f1660 <thread_status+352>) at ./nptl/futex-internal.c:57
# #1  __futex_abstimed_wait_common (cancel=true, private=0, abstime=0x0, clockid=0, expected=0, futex_word=0x7554735f1660 <thread_status+352>) at ./nptl/futex-internal.c:87
# #2  __GI___futex_abstimed_wait_cancelable64 (futex_word=futex_word
# entry=0x7554735f1660 <thread_status+352>, expected=expected
# entry=0, clockid=clockid
# entry=0, abstime=abstime
# entry=0x0, private=private
# entry=0) at ./nptl/futex-internal.c:139
# #3  0x00007554c5693a41 in __pthread_cond_wait_common (abstime=0x0, clockid=0, mutex=0x7554735f1610 <thread_status+272>, cond=0x7554735f1638 <thread_status+312>) at ./nptl/pthread_cond_wait.c:503
# #4  ___pthread_cond_wait (cond=0x7554735f1638 <thread_status+312>, mutex=0x7554735f1610 <thread_status+272>) at ./nptl/pthread_cond_wait.c:627
# #5  0x00007554714b85ec in blas_thread_server () from /home/jack/miniconda3/envs/root_new/lib/python3.13/site-packages/numpy/_core/../../../../libcblas.so.3
# #6  0x00007554c5694ac3 in start_thread (arg=<optimized out>) at ./nptl/pthread_create.c:442
# #7  0x00007554c57268c0 in clone3 () at ../sysdeps/unix/sysv/linux/x86_64/clone3.S:81
#
# Thread 15 (Thread 0x7554107ae640 (LWP 129393) "python"):
# #0  __futex_abstimed_wait_common64 (private=0, cancel=true, abstime=0x0, op=393, expected=0, futex_word=0x7554735f15e0 <thread_status+224>) at ./nptl/futex-internal.c:57
# #1  __futex_abstimed_wait_common (cancel=true, private=0, abstime=0x0, clockid=0, expected=0, futex_word=0x7554735f15e0 <thread_status+224>) at ./nptl/futex-internal.c:87
# #2  __GI___futex_abstimed_wait_cancelable64 (futex_word=futex_word
# entry=0x7554735f15e0 <thread_status+224>, expected=expected
# entry=0, clockid=clockid
# entry=0, abstime=abstime
# entry=0x0, private=private
# entry=0) at ./nptl/futex-internal.c:139
# #3  0x00007554c5693a41 in __pthread_cond_wait_common (abstime=0x0, clockid=0, mutex=0x7554735f1590 <thread_status+144>, cond=0x7554735f15b8 <thread_status+184>) at ./nptl/pthread_cond_wait.c:503
# #4  ___pthread_cond_wait (cond=0x7554735f15b8 <thread_status+184>, mutex=0x7554735f1590 <thread_status+144>) at ./nptl/pthread_cond_wait.c:627
# #5  0x00007554714b85ec in blas_thread_server () from /home/jack/miniconda3/envs/root_new/lib/python3.13/site-packages/numpy/_core/../../../../libcblas.so.3
# #6  0x00007554c5694ac3 in start_thread (arg=<optimized out>) at ./nptl/pthread_create.c:442
# #7  0x00007554c57268c0 in clone3 () at ../sysdeps/unix/sysv/linux/x86_64/clone3.S:81
#
# Thread 14 (Thread 0x755410faf640 (LWP 129392) "python"):
# #0  __futex_abstimed_wait_common64 (private=0, cancel=true, abstime=0x0, op=393, expected=0, futex_word=0x7554735f1560 <thread_status+96>) at ./nptl/futex-internal.c:57
# #1  __futex_abstimed_wait_common (cancel=true, private=0, abstime=0x0, clockid=0, expected=0, futex_word=0x7554735f1560 <thread_status+96>) at ./nptl/futex-internal.c:87
# #2  __GI___futex_abstimed_wait_cancelable64 (futex_word=futex_word
# entry=0x7554735f1560 <thread_status+96>, expected=expected
# entry=0, clockid=clockid
# entry=0, abstime=abstime
# entry=0x0, private=private
# entry=0) at ./nptl/futex-internal.c:139
# #3  0x00007554c5693a41 in __pthread_cond_wait_common (abstime=0x0, clockid=0, mutex=0x7554735f1510 <thread_status+16>, cond=0x7554735f1538 <thread_status+56>) at ./nptl/pthread_cond_wait.c:503
# #4  ___pthread_cond_wait (cond=0x7554735f1538 <thread_status+56>, mutex=0x7554735f1510 <thread_status+16>) at ./nptl/pthread_cond_wait.c:627
# #5  0x00007554714b85ec in blas_thread_server () from /home/jack/miniconda3/envs/root_new/lib/python3.13/site-packages/numpy/_core/../../../../libcblas.so.3
# #6  0x00007554c5694ac3 in start_thread (arg=<optimized out>) at ./nptl/pthread_create.c:442
# #7  0x00007554c57268c0 in clone3 () at ../sysdeps/unix/sysv/linux/x86_64/clone3.S:81
#
# Thread 13 (Thread 0x75547908e640 (LWP 129391) "python"):
# #0  __futex_abstimed_wait_common64 (private=96, cancel=true, abstime=0x75547908dae0, op=137, expected=0, futex_word=0x56b17c548c04 <_PyRuntime+96228>) at ./nptl/futex-internal.c:57
# #1  __futex_abstimed_wait_common (cancel=true, private=96, abstime=0x75547908dae0, clockid=0, expected=0, futex_word=0x56b17c548c04 <_PyRuntime+96228>) at ./nptl/futex-internal.c:87
# #2  __GI___futex_abstimed_wait_cancelable64 (futex_word=futex_word
# entry=0x56b17c548c04 <_PyRuntime+96228>, expected=expected
# entry=0, clockid=clockid
# entry=1, abstime=abstime
# entry=0x75547908dae0, private=private
# entry=0) at ./nptl/futex-internal.c:139
# #3  0x00007554c5693e9b in __pthread_cond_wait_common (abstime=0x75547908dae0, clockid=1, mutex=0x56b17c548c08 <_PyRuntime+96232>, cond=0x56b17c548bd8 <_PyRuntime+96184>) at ./nptl/pthread_cond_wait.c:503
# #4  ___pthread_cond_timedwait64 (cond=cond
# entry=0x56b17c548bd8 <_PyRuntime+96184>, mutex=mutex
# entry=0x56b17c548c08 <_PyRuntime+96232>, abstime=abstime
# entry=0x75547908dae0) at ./nptl/pthread_cond_wait.c:652
# #5  0x000056b17c1b0fa7 in PyCOND_TIMEDWAIT (us=<optimized out>, mut=<optimized out>, cond=0x56b17c548bd8 <_PyRuntime+96184>) at /usr/local/src/conda/python-3.13.5/Python/condvar.h:74
# #6  take_gil (tstate=0x56b19c5d7ef0) at /usr/local/src/conda/python-3.13.5/Python/ceval_gil.c:331
# #7  0x000056b17c229a82 in _PyEval_AcquireLock (tstate=0x56b19c5d7ef0) at /usr/local/src/conda/python-3.13.5/Python/ceval_gil.c:585
# #8  _PyThreadState_Attach (tstate=0x56b19c5d7ef0) at /usr/local/src/conda/python-3.13.5/Python/pystate.c:2089
# #9  PyEval_RestoreThread (tstate=0x56b19c5d7ef0) at /usr/local/src/conda/python-3.13.5/Python/ceval_gil.c:651
# #10 0x000056b17c313774 in pysleep (timeout=<optimized out>) at /usr/local/src/conda/python-3.13.5/Modules/timemodule.c:2271
# #11 time_sleep (self=<optimized out>, timeout_obj=<optimized out>) at /usr/local/src/conda/python-3.13.5/Modules/timemodule.c:408
# #12 0x000056b17c0bb3c8 in _PyEval_EvalFrameDefault (tstate=0x56b19c5d7ef0, frame=<optimized out>, throwflag=<optimized out>) at /usr/local/src/conda/python-3.13.5/Python/generated_cases.c.h:1266
# #13 0x000056b17c21b2a9 in _PyEval_EvalFrame (throwflag=0, frame=<optimized out>, tstate=0x56b19c5d7ef0) at /usr/local/src/conda/python-3.13.5/Include/internal/pycore_ceval.h:119
# #14 _PyEval_Vector (kwnames=0x0, argcount=1, args=0x75547908dda8, locals=0x0, func=0x7554c53019e0, tstate=0x56b19c5d7ef0) at /usr/local/src/conda/python-3.13.5/Python/ceval.c:1816
# #15 _PyFunction_Vectorcall (kwnames=0x0, nargsf=1, stack=0x75547908dda8, func=0x7554c53019e0) at /usr/local/src/conda/python-3.13.5/Objects/call.c:413
# #16 _PyObject_VectorcallTstate (kwnames=0x0, nargsf=1, args=0x75547908dda8, callable=0x7554c53019e0, tstate=0x56b19c5d7ef0) at /usr/local/src/conda/python-3.13.5/Include/internal/pycore_call.h:168
# #17 method_vectorcall (method=<optimized out>, args=0x56b17c546d20 <_PyRuntime+88320>, nargsf=<optimized out>, kwnames=<optimized out>) at /usr/local/src/conda/python-3.13.5/Objects/classobject.c:70
# #18 0x000056b17c3032ea in thread_run (boot_raw=0x56b19d31f830) at /usr/local/src/conda/python-3.13.5/Modules/_threadmodule.c:343
# #19 0x000056b17c303004 in pythread_wrapper (arg=<optimized out>) at /usr/local/src/conda/python-3.13.5/Python/thread_pthread.h:243
# #20 0x00007554c5694ac3 in start_thread (arg=<optimized out>) at ./nptl/pthread_create.c:442
# #21 0x00007554c57268c0 in clone3 () at ../sysdeps/unix/sysv/linux/x86_64/clone3.S:81
#
# Thread 12 (Thread 0x7554b0ff9640 (LWP 129367) "python"):
# #0  0x00007554c56e57f8 in __GI___clock_nanosleep (clock_id=clock_id
# entry=1, flags=flags
# entry=1, req=req
# entry=0x7554b0ff8b60, rem=rem
# entry=0x0) at ../sysdeps/unix/sysv/linux/clock_nanosleep.c:78
# #1  0x000056b17c31376a in pysleep (timeout=<optimized out>) at /usr/local/src/conda/python-3.13.5/Modules/timemodule.c:2262
# #2  time_sleep (self=<optimized out>, timeout_obj=<optimized out>) at /usr/local/src/conda/python-3.13.5/Modules/timemodule.c:408
# #3  0x000056b17c0bb3c8 in _PyEval_EvalFrameDefault (tstate=0x56b195605110, frame=<optimized out>, throwflag=<optimized out>) at /usr/local/src/conda/python-3.13.5/Python/generated_cases.c.h:1266
# #4  0x000056b17c21b2a9 in _PyEval_EvalFrame (throwflag=0, frame=<optimized out>, tstate=0x56b195605110) at /usr/local/src/conda/python-3.13.5/Include/internal/pycore_ceval.h:119
# #5  _PyEval_Vector (kwnames=0x0, argcount=1, args=0x7554b0ff8da8, locals=0x0, func=0x7554c53019e0, tstate=0x56b195605110) at /usr/local/src/conda/python-3.13.5/Python/ceval.c:1816
# #6  _PyFunction_Vectorcall (kwnames=0x0, nargsf=1, stack=0x7554b0ff8da8, func=0x7554c53019e0) at /usr/local/src/conda/python-3.13.5/Objects/call.c:413
# #7  _PyObject_VectorcallTstate (kwnames=0x0, nargsf=1, args=0x7554b0ff8da8, callable=0x7554c53019e0, tstate=0x56b195605110) at /usr/local/src/conda/python-3.13.5/Include/internal/pycore_call.h:168
# #8  method_vectorcall (method=<optimized out>, args=0x56b17c546d20 <_PyRuntime+88320>, nargsf=<optimized out>, kwnames=<optimized out>) at /usr/local/src/conda/python-3.13.5/Objects/classobject.c:70
# #9  0x000056b17c3032ea in thread_run (boot_raw=0x56b195e24a90) at /usr/local/src/conda/python-3.13.5/Modules/_threadmodule.c:343
# #10 0x000056b17c303004 in pythread_wrapper (arg=<optimized out>) at /usr/local/src/conda/python-3.13.5/Python/thread_pthread.h:243
# #11 0x00007554c5694ac3 in start_thread (arg=<optimized out>) at ./nptl/pthread_create.c:442
# #12 0x00007554c57268c0 in clone3 () at ../sysdeps/unix/sysv/linux/x86_64/clone3.S:81
#
# Thread 11 (Thread 0x7554b17fa640 (LWP 129366) "python"):
# #0  __futex_abstimed_wait_common64 (private=-1018336034, cancel=true, abstime=0x7554b17f9a30, op=137, expected=0, futex_word=0x56b17c548c04 <_PyRuntime+96228>) at ./nptl/futex-internal.c:57
# #1  __futex_abstimed_wait_common (cancel=true, private=-1018336034, abstime=0x7554b17f9a30, clockid=-1610562856, expected=0, futex_word=0x56b17c548c04 <_PyRuntime+96228>) at ./nptl/futex-internal.c:87
# #2  __GI___futex_abstimed_wait_cancelable64 (futex_word=futex_word
# entry=0x56b17c548c04 <_PyRuntime+96228>, expected=expected
# entry=0, clockid=clockid
# entry=1, abstime=abstime
# entry=0x7554b17f9a30, private=private
# entry=0) at ./nptl/futex-internal.c:139
# #3  0x00007554c5693e9b in __pthread_cond_wait_common (abstime=0x7554b17f9a30, clockid=1, mutex=0x56b17c548c08 <_PyRuntime+96232>, cond=0x56b17c548bd8 <_PyRuntime+96184>) at ./nptl/pthread_cond_wait.c:503
# #4  ___pthread_cond_timedwait64 (cond=cond
# entry=0x56b17c548bd8 <_PyRuntime+96184>, mutex=mutex
# entry=0x56b17c548c08 <_PyRuntime+96232>, abstime=abstime
# entry=0x7554b17f9a30) at ./nptl/pthread_cond_wait.c:652
# #5  0x000056b17c1b0fa7 in PyCOND_TIMEDWAIT (us=<optimized out>, mut=<optimized out>, cond=0x56b17c548bd8 <_PyRuntime+96184>) at /usr/local/src/conda/python-3.13.5/Python/condvar.h:74
# #6  take_gil (tstate=0x56b19553b1c0) at /usr/local/src/conda/python-3.13.5/Python/ceval_gil.c:331
# #7  0x000056b17c229a82 in _PyEval_AcquireLock (tstate=0x56b19553b1c0) at /usr/local/src/conda/python-3.13.5/Python/ceval_gil.c:585
# #8  _PyThreadState_Attach (tstate=0x56b19553b1c0) at /usr/local/src/conda/python-3.13.5/Python/pystate.c:2089
# #9  PyEval_RestoreThread (tstate=tstate
# entry=0x56b19553b1c0) at /usr/local/src/conda/python-3.13.5/Python/ceval_gil.c:651
# #10 0x00007554c358456a in begin_transaction (self=0x7554c0433100) at /usr/local/src/conda/python-3.13.5/Modules/_sqlite/cursor.c:500
# #11 _pysqlite_query_execute (self=0x7554092a90c0, multiple=0, operation=<optimized out>, second_argument=<optimized out>) at /usr/local/src/conda/python-3.13.5/Modules/_sqlite/cursor.c:870
# #12 0x00007554c35831f0 in pysqlite_connection_execute_impl (parameters=<optimized out>, sql=0x7554c3600e40, self=0x7554c0433100) at /usr/local/src/conda/python-3.13.5/Modules/_sqlite/connection.c:1820
# #13 pysqlite_connection_execute (self=0x7554c0433100, args=<optimized out>, nargs=<optimized out>) at /usr/local/src/conda/python-3.13.5/Modules/_sqlite/clinic/connection.c.h:1138
# #14 0x000056b17c0bae96 in _PyEval_EvalFrameDefault (tstate=0x56b19553b1c0, frame=<optimized out>, throwflag=<optimized out>) at /usr/local/src/conda/python-3.13.5/Python/generated_cases.c.h:1642
# #15 0x000056b17c21b2a9 in _PyEval_EvalFrame (throwflag=0, frame=<optimized out>, tstate=0x56b19553b1c0) at /usr/local/src/conda/python-3.13.5/Include/internal/pycore_ceval.h:119
# #16 _PyEval_Vector (kwnames=0x0, argcount=1, args=0x7554b17f9da8, locals=0x0, func=0x7554c53019e0, tstate=0x56b19553b1c0) at /usr/local/src/conda/python-3.13.5/Python/ceval.c:1816
# #17 _PyFunction_Vectorcall (kwnames=0x0, nargsf=1, stack=0x7554b17f9da8, func=0x7554c53019e0) at /usr/local/src/conda/python-3.13.5/Objects/call.c:413
# #18 _PyObject_VectorcallTstate (kwnames=0x0, nargsf=1, args=0x7554b17f9da8, callable=0x7554c53019e0, tstate=0x56b19553b1c0) at /usr/local/src/conda/python-3.13.5/Include/internal/pycore_call.h:168
# #19 method_vectorcall (method=<optimized out>, args=0x56b17c546d20 <_PyRuntime+88320>, nargsf=<optimized out>, kwnames=<optimized out>) at /usr/local/src/conda/python-3.13.5/Objects/classobject.c:70
# #20 0x000056b17c3032ea in thread_run (boot_raw=0x56b195dfb3d0) at /usr/local/src/conda/python-3.13.5/Modules/_threadmodule.c:343
# #21 0x000056b17c303004 in pythread_wrapper (arg=<optimized out>) at /usr/local/src/conda/python-3.13.5/Python/thread_pthread.h:243
# #22 0x00007554c5694ac3 in start_thread (arg=<optimized out>) at ./nptl/pthread_create.c:442
# #23 0x00007554c57268c0 in clone3 () at ../sysdeps/unix/sysv/linux/x86_64/clone3.S:81
#
# Thread 10 (Thread 0x7554b1ffb640 (LWP 129364) "python"):
# #0  0x00007554c5725e9e in epoll_wait (epfd=19, events=events
# entry=0x7554c268d9e0, maxevents=maxevents
# entry=3, timeout=timeout
# entry=-1) at ../sysdeps/unix/sysv/linux/epoll_wait.c:30
# #1  0x00007554c52b1842 in select_epoll_poll_impl (maxevents=<optimized out>, timeout_obj=<optimized out>, self=0x7554c2783750) at /usr/local/src/conda/python-3.13.5/Modules/selectmodule.c:1630
# #2  select_epoll_poll (self=0x7554c2783750, args=<optimized out>, nargs=<optimized out>, kwnames=<optimized out>) at /usr/local/src/conda/python-3.13.5/Modules/clinic/selectmodule.c.h:1007
# #3  0x000056b17c0b956f in _PyEval_EvalFrameDefault (tstate=0x56b1954e01b0, frame=<optimized out>, throwflag=<optimized out>) at /usr/local/src/conda/python-3.13.5/Python/generated_cases.c.h:1694
# #4  0x000056b17c21b2a9 in _PyEval_EvalFrame (throwflag=0, frame=<optimized out>, tstate=0x56b1954e01b0) at /usr/local/src/conda/python-3.13.5/Include/internal/pycore_ceval.h:119
# #5  _PyEval_Vector (kwnames=0x0, argcount=1, args=0x7554b1ffada8, locals=0x0, func=0x7554c53019e0, tstate=0x56b1954e01b0) at /usr/local/src/conda/python-3.13.5/Python/ceval.c:1816
# #6  _PyFunction_Vectorcall (kwnames=0x0, nargsf=1, stack=0x7554b1ffada8, func=0x7554c53019e0) at /usr/local/src/conda/python-3.13.5/Objects/call.c:413
# #7  _PyObject_VectorcallTstate (kwnames=0x0, nargsf=1, args=0x7554b1ffada8, callable=0x7554c53019e0, tstate=0x56b1954e01b0) at /usr/local/src/conda/python-3.13.5/Include/internal/pycore_call.h:168
# #8  method_vectorcall (method=<optimized out>, args=0x56b17c546d20 <_PyRuntime+88320>, nargsf=<optimized out>, kwnames=<optimized out>) at /usr/local/src/conda/python-3.13.5/Objects/classobject.c:70
# #9  0x000056b17c3032ea in thread_run (boot_raw=0x56b195610be0) at /usr/local/src/conda/python-3.13.5/Modules/_threadmodule.c:343
# #10 0x000056b17c303004 in pythread_wrapper (arg=<optimized out>) at /usr/local/src/conda/python-3.13.5/Python/thread_pthread.h:243
# #11 0x00007554c5694ac3 in start_thread (arg=<optimized out>) at ./nptl/pthread_create.c:442
# #12 0x00007554c57268c0 in clone3 () at ../sysdeps/unix/sysv/linux/x86_64/clone3.S:81
#
# Thread 9 (Thread 0x7554b27fc640 (LWP 129363) "python"):
# #0  __GI___libc_read (nbytes=1000, buf=0x7554a8000b90, fd=40) at ../sysdeps/unix/sysv/linux/read.c:26
# #1  __GI___libc_read (fd=fd
# entry=40, buf=buf
# entry=0x7554a8000b90, nbytes=nbytes
# entry=1000) at ../sysdeps/unix/sysv/linux/read.c:24
# #2  0x000056b17c2aef0c in read (__nbytes=<optimized out>, __buf=<optimized out>, __fd=<optimized out>, __fd=<optimized out>, __buf=<optimized out>, __nbytes=<optimized out>) at /home/conda/feedstock_root/build_artifacts/python-split_1750061167312/_build_env/x86_64-conda-linux-gnu/sysroot/usr/include/bits/unistd.h:44
# #3  _Py_read (fd=40, buf=0x7554a8000b90, count=1000) at /usr/local/src/conda/python-3.13.5/Python/fileutils.c:1883
# #4  0x000056b17c2f76d6 in os_read_impl (module=<optimized out>, length=1000, fd=40) at /usr/local/src/conda/python-3.13.5/Modules/posixmodule.c:11398
# #5  os_read (module=<optimized out>, args=<optimized out>, nargs=<optimized out>) at /usr/local/src/conda/python-3.13.5/Modules/clinic/posixmodule.c.h:7407
# #6  0x000056b17c0b3b73 in _PyEval_EvalFrameDefault (tstate=0x56b195485b90, frame=<optimized out>, throwflag=<optimized out>) at /usr/local/src/conda/python-3.13.5/Python/generated_cases.c.h:1167
# #7  0x000056b17c21b2a9 in _PyEval_EvalFrame (throwflag=0, frame=<optimized out>, tstate=0x56b195485b90) at /usr/local/src/conda/python-3.13.5/Include/internal/pycore_ceval.h:119
# #8  _PyEval_Vector (kwnames=0x0, argcount=1, args=0x7554b27fbb28, locals=0x0, func=0x7554c2918f40, tstate=0x56b195485b90) at /usr/local/src/conda/python-3.13.5/Python/ceval.c:1816
# #9  _PyFunction_Vectorcall (kwnames=0x0, nargsf=1, stack=0x7554b27fbb28, func=0x7554c2918f40) at /usr/local/src/conda/python-3.13.5/Objects/call.c:413
# #10 _PyObject_VectorcallTstate (kwnames=0x0, nargsf=1, args=0x7554b27fbb28, callable=0x7554c2918f40, tstate=0x56b195485b90) at /usr/local/src/conda/python-3.13.5/Include/internal/pycore_call.h:168
# #11 method_vectorcall (method=<optimized out>, args=0x56b17c546d20 <_PyRuntime+88320>, nargsf=<optimized out>, kwnames=<optimized out>) at /usr/local/src/conda/python-3.13.5/Objects/classobject.c:70
# #12 0x000056b17c0b3a1c in PyObject_Call (kwargs=0x7554c2661f00, args=0x56b17c546d08 <_PyRuntime+88296>, callable=0x7554c2661fc0) at /usr/local/src/conda/python-3.13.5/Objects/call.c:373
# #13 PyCFunction_Call (kwargs=0x7554c2661f00, args=0x56b17c546d08 <_PyRuntime+88296>, callable=0x7554c2661fc0) at /usr/local/src/conda/python-3.13.5/Objects/call.c:381
# #14 _PyEval_EvalFrameDefault (tstate=0x56b195485b90, frame=<optimized out>, throwflag=<optimized out>) at /usr/local/src/conda/python-3.13.5/Python/generated_cases.c.h:1355
# #15 0x000056b17c21b2a9 in _PyEval_EvalFrame (throwflag=0, frame=<optimized out>, tstate=0x56b195485b90) at /usr/local/src/conda/python-3.13.5/Include/internal/pycore_ceval.h:119
# #16 _PyEval_Vector (kwnames=0x0, argcount=1, args=0x7554b27fbda8, locals=0x0, func=0x7554c53019e0, tstate=0x56b195485b90) at /usr/local/src/conda/python-3.13.5/Python/ceval.c:1816
# #17 _PyFunction_Vectorcall (kwnames=0x0, nargsf=1, stack=0x7554b27fbda8, func=0x7554c53019e0) at /usr/local/src/conda/python-3.13.5/Objects/call.c:413
# #18 _PyObject_VectorcallTstate (kwnames=0x0, nargsf=1, args=0x7554b27fbda8, callable=0x7554c53019e0, tstate=0x56b195485b90) at /usr/local/src/conda/python-3.13.5/Include/internal/pycore_call.h:168
# #19 method_vectorcall (method=<optimized out>, args=0x56b17c546d20 <_PyRuntime+88320>, nargsf=<optimized out>, kwnames=<optimized out>) at /usr/local/src/conda/python-3.13.5/Objects/classobject.c:70
# #20 0x000056b17c3032ea in thread_run (boot_raw=0x56b195636fd0) at /usr/local/src/conda/python-3.13.5/Modules/_threadmodule.c:343
# #21 0x000056b17c303004 in pythread_wrapper (arg=<optimized out>) at /usr/local/src/conda/python-3.13.5/Python/thread_pthread.h:243
# #22 0x00007554c5694ac3 in start_thread (arg=<optimized out>) at ./nptl/pthread_create.c:442
# #23 0x00007554c57268c0 in clone3 () at ../sysdeps/unix/sysv/linux/x86_64/clone3.S:81
#
# Thread 8 (Thread 0x7554b2ffd640 (LWP 129362) "python"):
# #0  __GI___libc_read (nbytes=1000, buf=0x7554a4000b90, fd=37) at ../sysdeps/unix/sysv/linux/read.c:26
# #1  __GI___libc_read (fd=fd
# entry=37, buf=buf
# entry=0x7554a4000b90, nbytes=nbytes
# entry=1000) at ../sysdeps/unix/sysv/linux/read.c:24
# #2  0x000056b17c2aef0c in read (__nbytes=<optimized out>, __buf=<optimized out>, __fd=<optimized out>, __fd=<optimized out>, __buf=<optimized out>, __nbytes=<optimized out>) at /home/conda/feedstock_root/build_artifacts/python-split_1750061167312/_build_env/x86_64-conda-linux-gnu/sysroot/usr/include/bits/unistd.h:44
# #3  _Py_read (fd=37, buf=0x7554a4000b90, count=1000) at /usr/local/src/conda/python-3.13.5/Python/fileutils.c:1883
# #4  0x000056b17c2f76d6 in os_read_impl (module=<optimized out>, length=1000, fd=37) at /usr/local/src/conda/python-3.13.5/Modules/posixmodule.c:11398
# #5  os_read (module=<optimized out>, args=<optimized out>, nargs=<optimized out>) at /usr/local/src/conda/python-3.13.5/Modules/clinic/posixmodule.c.h:7407
# #6  0x000056b17c1eacd3 in cfunction_vectorcall_FASTCALL (func=0x7554c5991170, args=0x7554c3bc11f0, nargsf=9223372036854775810, kwnames=<optimized out>) at /usr/local/src/conda/python-3.13.5/Objects/methodobject.c:425
# #7  0x000056b17c1c70fe in _PyObject_VectorcallTstate (kwnames=<optimized out>, nargsf=<optimized out>, args=<optimized out>, callable=0x7554c5991170, tstate=0x56b1953e7e60) at /usr/local/src/conda/python-3.13.5/Include/internal/pycore_call.h:168
# #8  PyObject_Vectorcall (callable=0x7554c5991170, args=<optimized out>, nargsf=<optimized out>, kwnames=<optimized out>) at /usr/local/src/conda/python-3.13.5/Objects/call.c:327
# #9  0x000056b17c0b3e73 in _PyEval_EvalFrameDefault (tstate=0x56b1953e7e60, frame=<optimized out>, throwflag=<optimized out>) at /usr/local/src/conda/python-3.13.5/Python/generated_cases.c.h:813
# #10 0x000056b17c21b2a9 in _PyEval_EvalFrame (throwflag=0, frame=<optimized out>, tstate=0x56b1953e7e60) at /usr/local/src/conda/python-3.13.5/Include/internal/pycore_ceval.h:119
# #11 _PyEval_Vector (kwnames=0x0, argcount=1, args=0x7554b2ffcb28, locals=0x0, func=0x7554c2918f40, tstate=0x56b1953e7e60) at /usr/local/src/conda/python-3.13.5/Python/ceval.c:1816
# #12 _PyFunction_Vectorcall (kwnames=0x0, nargsf=1, stack=0x7554b2ffcb28, func=0x7554c2918f40) at /usr/local/src/conda/python-3.13.5/Objects/call.c:413
# #13 _PyObject_VectorcallTstate (kwnames=0x0, nargsf=1, args=0x7554b2ffcb28, callable=0x7554c2918f40, tstate=0x56b1953e7e60) at /usr/local/src/conda/python-3.13.5/Include/internal/pycore_call.h:168
# #14 method_vectorcall (method=<optimized out>, args=0x56b17c546d20 <_PyRuntime+88320>, nargsf=<optimized out>, kwnames=<optimized out>) at /usr/local/src/conda/python-3.13.5/Objects/classobject.c:70
# #15 0x000056b17c0b3a1c in PyObject_Call (kwargs=0x7554c2656940, args=0x56b17c546d08 <_PyRuntime+88296>, callable=0x7554c264ad80) at /usr/local/src/conda/python-3.13.5/Objects/call.c:373
# #16 PyCFunction_Call (kwargs=0x7554c2656940, args=0x56b17c546d08 <_PyRuntime+88296>, callable=0x7554c264ad80) at /usr/local/src/conda/python-3.13.5/Objects/call.c:381
# #17 _PyEval_EvalFrameDefault (tstate=0x56b1953e7e60, frame=<optimized out>, throwflag=<optimized out>) at /usr/local/src/conda/python-3.13.5/Python/generated_cases.c.h:1355
# #18 0x000056b17c21b2a9 in _PyEval_EvalFrame (throwflag=0, frame=<optimized out>, tstate=0x56b1953e7e60) at /usr/local/src/conda/python-3.13.5/Include/internal/pycore_ceval.h:119
# #19 _PyEval_Vector (kwnames=0x0, argcount=1, args=0x7554b2ffcda8, locals=0x0, func=0x7554c53019e0, tstate=0x56b1953e7e60) at /usr/local/src/conda/python-3.13.5/Python/ceval.c:1816
# #20 _PyFunction_Vectorcall (kwnames=0x0, nargsf=1, stack=0x7554b2ffcda8, func=0x7554c53019e0) at /usr/local/src/conda/python-3.13.5/Objects/call.c:413
# #21 _PyObject_VectorcallTstate (kwnames=0x0, nargsf=1, args=0x7554b2ffcda8, callable=0x7554c53019e0, tstate=0x56b1953e7e60) at /usr/local/src/conda/python-3.13.5/Include/internal/pycore_call.h:168
# #22 method_vectorcall (method=<optimized out>, args=0x56b17c546d20 <_PyRuntime+88320>, nargsf=<optimized out>, kwnames=<optimized out>) at /usr/local/src/conda/python-3.13.5/Objects/classobject.c:70
# #23 0x000056b17c3032ea in thread_run (boot_raw=0x56b1954c27f0) at /usr/local/src/conda/python-3.13.5/Modules/_threadmodule.c:343
# #24 0x000056b17c303004 in pythread_wrapper (arg=<optimized out>) at /usr/local/src/conda/python-3.13.5/Python/thread_pthread.h:243
# #25 0x00007554c5694ac3 in start_thread (arg=<optimized out>) at ./nptl/pthread_create.c:442
# #26 0x00007554c57268c0 in clone3 () at ../sysdeps/unix/sysv/linux/x86_64/clone3.S:81
#
# Thread 7 (Thread 0x7554b37fe640 (LWP 129361) "ZMQbg/IO/0"):
# #0  0x00007554c5725e9e in epoll_wait (epfd=34, events=0x7554b37fd160, maxevents=256, timeout=-1) at ../sysdeps/unix/sysv/linux/epoll_wait.c:30
# #1  0x00007554c51e8f59 in zmq::epoll_t::loop() () from /home/jack/miniconda3/envs/root_new/bin/../lib/libzmq.so.5
# #2  0x00007554c52242bf in thread_routine () from /home/jack/miniconda3/envs/root_new/bin/../lib/libzmq.so.5
# #3  0x00007554c5694ac3 in start_thread (arg=<optimized out>) at ./nptl/pthread_create.c:442
# #4  0x00007554c57268c0 in clone3 () at ../sysdeps/unix/sysv/linux/x86_64/clone3.S:81
#
# Thread 6 (Thread 0x7554b3fff640 (LWP 129360) "ZMQbg/Reaper"):
# #0  0x00007554c5725e9e in epoll_wait (epfd=32, events=0x7554b3ffe160, maxevents=256, timeout=-1) at ../sysdeps/unix/sysv/linux/epoll_wait.c:30
# #1  0x00007554c51e8f59 in zmq::epoll_t::loop() () from /home/jack/miniconda3/envs/root_new/bin/../lib/libzmq.so.5
# #2  0x00007554c52242bf in thread_routine () from /home/jack/miniconda3/envs/root_new/bin/../lib/libzmq.so.5
# #3  0x00007554c5694ac3 in start_thread (arg=<optimized out>) at ./nptl/pthread_create.c:442
# #4  0x00007554c57268c0 in clone3 () at ../sysdeps/unix/sysv/linux/x86_64/clone3.S:81
#
# Thread 5 (Thread 0x7554c0e2d640 (LWP 129359) "python"):
# #0  0x00007554c5718c3f in __GI___poll (fds=0x7554c0e2c7e0, nfds=2, timeout=-1) at ../sysdeps/unix/sysv/linux/poll.c:29
# #1  0x00007554c5231d66 in zmq_poll () from /home/jack/miniconda3/envs/root_new/bin/../lib/libzmq.so.5
# #2  0x00007554c5204387 in zmq::proxy_steerable(zmq::socket_base_t*, zmq::socket_base_t*, zmq::socket_base_t*, zmq::socket_base_t*) () from /home/jack/miniconda3/envs/root_new/bin/../lib/libzmq.so.5
# #3  0x00007554c5270e6f in ?? () from /home/jack/miniconda3/envs/root_new/lib/python3.13/site-packages/zmq/backend/cython/_zmq.abi3.so
# #4  0x000056b17c1c70fe in _PyObject_VectorcallTstate (kwnames=<optimized out>, nargsf=<optimized out>, args=<optimized out>, callable=0x7554c4da0d50, tstate=0x56b1953bd050) at /usr/local/src/conda/python-3.13.5/Include/internal/pycore_call.h:168
# #5  PyObject_Vectorcall (callable=0x7554c4da0d50, args=<optimized out>, nargsf=<optimized out>, kwnames=<optimized out>) at /usr/local/src/conda/python-3.13.5/Objects/call.c:327
# #6  0x000056b17c0b3e73 in _PyEval_EvalFrameDefault (tstate=0x56b1953bd050, frame=<optimized out>, throwflag=<optimized out>) at /usr/local/src/conda/python-3.13.5/Python/generated_cases.c.h:813
# #7  0x000056b17c21b2a9 in _PyEval_EvalFrame (throwflag=0, frame=<optimized out>, tstate=0x56b1953bd050) at /usr/local/src/conda/python-3.13.5/Include/internal/pycore_ceval.h:119
# #8  _PyEval_Vector (kwnames=0x0, argcount=1, args=0x7554c0e2cda8, locals=0x0, func=0x7554c53019e0, tstate=0x56b1953bd050) at /usr/local/src/conda/python-3.13.5/Python/ceval.c:1816
# #9  _PyFunction_Vectorcall (kwnames=0x0, nargsf=1, stack=0x7554c0e2cda8, func=0x7554c53019e0) at /usr/local/src/conda/python-3.13.5/Objects/call.c:413
# #10 _PyObject_VectorcallTstate (kwnames=0x0, nargsf=1, args=0x7554c0e2cda8, callable=0x7554c53019e0, tstate=0x56b1953bd050) at /usr/local/src/conda/python-3.13.5/Include/internal/pycore_call.h:168
# #11 method_vectorcall (method=<optimized out>, args=0x56b17c546d20 <_PyRuntime+88320>, nargsf=<optimized out>, kwnames=<optimized out>) at /usr/local/src/conda/python-3.13.5/Objects/classobject.c:70
# #12 0x000056b17c3032ea in thread_run (boot_raw=0x56b195bfac50) at /usr/local/src/conda/python-3.13.5/Modules/_threadmodule.c:343
# #13 0x000056b17c303004 in pythread_wrapper (arg=<optimized out>) at /usr/local/src/conda/python-3.13.5/Python/thread_pthread.h:243
# #14 0x00007554c5694ac3 in start_thread (arg=<optimized out>) at ./nptl/pthread_create.c:442
# #15 0x00007554c57268c0 in clone3 () at ../sysdeps/unix/sysv/linux/x86_64/clone3.S:81
#
# Thread 4 (Thread 0x7554c162e640 (LWP 129358) "python"):
# #0  __futex_abstimed_wait_common64 (private=0, cancel=true, abstime=0x7554c162c830, op=137, expected=0, futex_word=0x56b17c548c04 <_PyRuntime+96228>) at ./nptl/futex-internal.c:57
# #1  __futex_abstimed_wait_common (cancel=true, private=0, abstime=0x7554c162c830, clockid=-982431420, expected=0, futex_word=0x56b17c548c04 <_PyRuntime+96228>) at ./nptl/futex-internal.c:87
# #2  __GI___futex_abstimed_wait_cancelable64 (futex_word=futex_word
# entry=0x56b17c548c04 <_PyRuntime+96228>, expected=expected
# entry=0, clockid=clockid
# entry=1, abstime=abstime
# entry=0x7554c162c830, private=private
# entry=0) at ./nptl/futex-internal.c:139
# #3  0x00007554c5693e9b in __pthread_cond_wait_common (abstime=0x7554c162c830, clockid=1, mutex=0x56b17c548c08 <_PyRuntime+96232>, cond=0x56b17c548bd8 <_PyRuntime+96184>) at ./nptl/pthread_cond_wait.c:503
# #4  ___pthread_cond_timedwait64 (cond=cond
# entry=0x56b17c548bd8 <_PyRuntime+96184>, mutex=mutex
# entry=0x56b17c548c08 <_PyRuntime+96232>, abstime=abstime
# entry=0x7554c162c830) at ./nptl/pthread_cond_wait.c:652
# #5  0x000056b17c1b0fa7 in PyCOND_TIMEDWAIT (us=<optimized out>, mut=<optimized out>, cond=0x56b17c548bd8 <_PyRuntime+96184>) at /usr/local/src/conda/python-3.13.5/Python/condvar.h:74
# #6  take_gil (tstate=0x56b195306ea0) at /usr/local/src/conda/python-3.13.5/Python/ceval_gil.c:331
# #7  0x000056b17c229a82 in _PyEval_AcquireLock (tstate=0x56b195306ea0) at /usr/local/src/conda/python-3.13.5/Python/ceval_gil.c:585
# #8  _PyThreadState_Attach (tstate=0x56b195306ea0) at /usr/local/src/conda/python-3.13.5/Python/pystate.c:2089
# #9  PyEval_RestoreThread (tstate=0x56b195306ea0) at /usr/local/src/conda/python-3.13.5/Python/ceval_gil.c:651
# #10 0x00007554c527dcdc in ?? () from /home/jack/miniconda3/envs/root_new/lib/python3.13/site-packages/zmq/backend/cython/_zmq.abi3.so
# #11 0x00007554c527edc6 in ?? () from /home/jack/miniconda3/envs/root_new/lib/python3.13/site-packages/zmq/backend/cython/_zmq.abi3.so
# #12 0x00007554c5279f06 in ?? () from /home/jack/miniconda3/envs/root_new/lib/python3.13/site-packages/zmq/backend/cython/_zmq.abi3.so
# #13 0x000056b17c1c70fe in _PyObject_VectorcallTstate (kwnames=<optimized out>, nargsf=<optimized out>, args=<optimized out>, callable=0x7554c4da0510, tstate=0x56b195306ea0) at /usr/local/src/conda/python-3.13.5/Include/internal/pycore_call.h:168
# #14 PyObject_Vectorcall (callable=0x7554c4da0510, args=<optimized out>, nargsf=<optimized out>, kwnames=<optimized out>) at /usr/local/src/conda/python-3.13.5/Objects/call.c:327
# #15 0x000056b17c0ba341 in _PyEval_EvalFrameDefault (tstate=0x56b195306ea0, frame=<optimized out>, throwflag=<optimized out>) at /usr/local/src/conda/python-3.13.5/Python/generated_cases.c.h:1502
# #16 0x000056b17c21b1d3 in _PyEval_EvalFrame (throwflag=0, frame=<optimized out>, tstate=0x56b195306ea0) at /usr/local/src/conda/python-3.13.5/Include/internal/pycore_ceval.h:119
# #17 _PyEval_Vector (kwnames=0x75540aaf2510, argcount=2, args=0x75540aaf23d0, locals=0x0, func=0x7554c4539da0, tstate=0x56b195306ea0) at /usr/local/src/conda/python-3.13.5/Python/ceval.c:1816
# #18 _PyFunction_Vectorcall (kwnames=0x75540aaf2510, nargsf=2, stack=0x75540aaf23d0, func=0x7554c4539da0) at /usr/local/src/conda/python-3.13.5/Objects/call.c:413
# #19 _PyObject_VectorcallTstate (kwnames=0x75540aaf2510, nargsf=2, args=0x75540aaf23d0, callable=0x7554c4539da0, tstate=0x56b195306ea0) at /usr/local/src/conda/python-3.13.5/Include/internal/pycore_call.h:168
# #20 method_vectorcall (method=method
# entry=0x75540aa4dfc0, args=args
# entry=0x75540aaf23d8, nargsf=<optimized out>, kwnames=kwnames
# entry=0x75540b03ac50) at /usr/local/src/conda/python-3.13.5/Objects/classobject.c:62
# #21 0x000056b17c29674b in _PyVectorcall_Call (kwargs=<optimized out>, tuple=<optimized out>, callable=0x75540aa4dfc0, func=0x56b17c21ae00 <method_vectorcall>, tstate=0x56b195306ea0) at /usr/local/src/conda/python-3.13.5/Objects/call.c:285
# #22 _PyObject_Call (tstate=0x56b195306ea0, callable=0x75540aa4dfc0, args=<optimized out>, kwargs=<optimized out>) at /usr/local/src/conda/python-3.13.5/Objects/call.c:348
# #23 0x000056b17c0b3a1c in PyObject_Call (kwargs=0x75540aa2fcc0, args=0x75540adee860, callable=0x75540aa4dfc0) at /usr/local/src/conda/python-3.13.5/Objects/call.c:373
# #24 PyCFunction_Call (kwargs=0x75540aa2fcc0, args=0x75540adee860, callable=0x75540aa4dfc0) at /usr/local/src/conda/python-3.13.5/Objects/call.c:381
# #25 _PyEval_EvalFrameDefault (tstate=0x56b195306ea0, frame=<optimized out>, throwflag=<optimized out>) at /usr/local/src/conda/python-3.13.5/Python/generated_cases.c.h:1355
# #26 0x000056b17c21b1d3 in _PyEval_EvalFrame (throwflag=0, frame=<optimized out>, tstate=0x56b195306ea0) at /usr/local/src/conda/python-3.13.5/Include/internal/pycore_ceval.h:119
# #27 _PyEval_Vector (kwnames=0x75540aaf23d0, argcount=2, args=0x75540aaf2270, locals=0x0, func=0x7554c2918ae0, tstate=0x56b195306ea0) at /usr/local/src/conda/python-3.13.5/Python/ceval.c:1816
# #28 _PyFunction_Vectorcall (kwnames=0x75540aaf23d0, nargsf=2, stack=0x75540aaf2270, func=0x7554c2918ae0) at /usr/local/src/conda/python-3.13.5/Objects/call.c:413
# #29 _PyObject_VectorcallTstate (kwnames=0x75540aaf23d0, nargsf=2, args=0x75540aaf2270, callable=0x7554c2918ae0, tstate=0x56b195306ea0) at /usr/local/src/conda/python-3.13.5/Include/internal/pycore_call.h:168
# #30 method_vectorcall (method=method
# entry=0x75540aa9ba80, args=args
# entry=0x75540aaf2278, nargsf=<optimized out>, kwnames=kwnames
# entry=0x75540adc9570) at /usr/local/src/conda/python-3.13.5/Objects/classobject.c:62
# #31 0x000056b17c29674b in _PyVectorcall_Call (kwargs=<optimized out>, tuple=<optimized out>, callable=0x75540aa9ba80, func=0x56b17c21ae00 <method_vectorcall>, tstate=0x56b195306ea0) at /usr/local/src/conda/python-3.13.5/Objects/call.c:285
# #32 _PyObject_Call (tstate=0x56b195306ea0, callable=0x75540aa9ba80, args=<optimized out>, kwargs=<optimized out>) at /usr/local/src/conda/python-3.13.5/Objects/call.c:348
# #33 0x000056b17c0b3a1c in PyObject_Call (kwargs=0x75540b4dc300, args=0x75540ac313f0, callable=0x75540aa9ba80) at /usr/local/src/conda/python-3.13.5/Objects/call.c:373
# #34 PyCFunction_Call (kwargs=0x75540b4dc300, args=0x75540ac313f0, callable=0x75540aa9ba80) at /usr/local/src/conda/python-3.13.5/Objects/call.c:381
# #35 _PyEval_EvalFrameDefault (tstate=0x56b195306ea0, frame=<optimized out>, throwflag=<optimized out>) at /usr/local/src/conda/python-3.13.5/Python/generated_cases.c.h:1355
# #36 0x000056b17c21b070 in _PyEval_EvalFrame (throwflag=0, frame=0x7554c50fc740, tstate=0x56b195306ea0) at /usr/local/src/conda/python-3.13.5/Include/internal/pycore_ceval.h:119
# #37 _PyEval_Vector (kwnames=<optimized out>, argcount=<optimized out>, args=0x7554c162d370, locals=0x0, func=0x7554c2918360, tstate=0x56b195306ea0) at /usr/local/src/conda/python-3.13.5/Python/ceval.c:1816
# #38 _PyFunction_Vectorcall (kwnames=<optimized out>, nargsf=<optimized out>, stack=0x7554c162d370, func=0x7554c2918360) at /usr/local/src/conda/python-3.13.5/Objects/call.c:413
# #39 _PyObject_VectorcallTstate (kwnames=<optimized out>, nargsf=<optimized out>, args=0x7554c162d370, callable=0x7554c2918360, tstate=0x56b195306ea0) at /usr/local/src/conda/python-3.13.5/Include/internal/pycore_call.h:168
# #40 method_vectorcall (method=<optimized out>, args=<optimized out>, nargsf=<optimized out>, kwnames=<optimized out>) at /usr/local/src/conda/python-3.13.5/Objects/classobject.c:92
# #41 0x000056b17c0b3a1c in PyObject_Call (kwargs=0x75540aaa7d00, args=0x75540b038940, callable=0x7554c26619c0) at /usr/local/src/conda/python-3.13.5/Objects/call.c:373
# #42 PyCFunction_Call (kwargs=0x75540aaa7d00, args=0x75540b038940, callable=0x7554c26619c0) at /usr/local/src/conda/python-3.13.5/Objects/call.c:381
# #43 _PyEval_EvalFrameDefault (tstate=0x56b195306ea0, frame=<optimized out>, throwflag=<optimized out>) at /usr/local/src/conda/python-3.13.5/Python/generated_cases.c.h:1355
# #44 0x000056b17c2bb262 in _PyObject_VectorcallTstate (tstate=0x56b195306ea0, callable=0x75540ab077e0, args=<optimized out>, nargsf=<optimized out>, kwnames=<optimized out>) at /usr/local/src/conda/python-3.13.5/Include/internal/pycore_call.h:168
# ...
# #48 0x000056b17c32834c in _PyObject_VectorcallTstate (tstate=0x56b17c5765b0 <_PyRuntime+283024>, callable=0x7554c264d9e0, args=<optimized out>, nargsf=<optimized out>, kwnames=<optimized out>) at /usr/local/src/conda/python-3.13.5/Include/internal/pycore_call.h:168
# #49 0x000056b17c180106 in context_run (self=0x7554c0285f00, args=0x7554c026b718, nargs=2, kwnames=0x0) at /usr/local/src/conda/python-3.13.5/Python/context.c:664
# #50 0x000056b17c1e051b in cfunction_vectorcall_FASTCALL_KEYWORDS (func=<optimized out>, args=0x7554c026b718, nargsf=<optimized out>, kwnames=<optimized out>) at /usr/local/src/conda/python-3.13.5/Objects/methodobject.c:441
# #51 0x000056b17c0b3a1c in PyObject_Call (kwargs=0x0, args=0x7554c026b700, callable=0x7554c0541580) at /usr/local/src/conda/python-3.13.5/Objects/call.c:373
# #52 PyCFunction_Call (kwargs=0x0, args=0x7554c026b700, callable=0x7554c0541580) at /usr/local/src/conda/python-3.13.5/Objects/call.c:381
# #53 _PyEval_EvalFrameDefault (tstate=0x56b17c5765b0 <_PyRuntime+283024>, frame=<optimized out>, throwflag=<optimized out>) at /usr/local/src/conda/python-3.13.5/Python/generated_cases.c.h:1355
# #54 0x000056b17c28a171 in PyEval_EvalCode (co=0x7554c5949e90, globals=<optimized out>, locals=0x7554c5540180) at /usr/local/src/conda/python-3.13.5/Python/ceval.c:604
# #55 0x000056b17c2a6699 in builtin_exec_impl (module=<optimized out>, closure=<optimized out>, locals=0x7554c5540180, globals=0x7554c5540180, source=0x7554c5949e90) at /usr/local/src/conda/python-3.13.5/Python/bltinmodule.c:1143
# #56 builtin_exec (module=<optimized out>, args=<optimized out>, nargs=<optimized out>, kwnames=<optimized out>) at /usr/local/src/conda/python-3.13.5/Python/clinic/bltinmodule.c.h:556
# #57 0x000056b17c1e051b in cfunction_vectorcall_FASTCALL_KEYWORDS (func=<optimized out>, args=0x7554c5aeb180, nargsf=<optimized out>, kwnames=<optimized out>) at /usr/local/src/conda/python-3.13.5/Objects/methodobject.c:441
# #58 0x000056b17c1c70fe in _PyObject_VectorcallTstate (kwnames=<optimized out>, nargsf=<optimized out>, args=<optimized out>, callable=0x7554c593a200, tstate=0x56b17c5765b0 <_PyRuntime+283024>) at /usr/local/src/conda/python-3.13.5/Include/internal/pycore_call.h:168
# #59 PyObject_Vectorcall (callable=0x7554c593a200, args=<optimized out>, nargsf=<optimized out>, kwnames=<optimized out>) at /usr/local/src/conda/python-3.13.5/Objects/call.c:327
# #60 0x000056b17c0b3e73 in _PyEval_EvalFrameDefault (tstate=0x56b17c5765b0 <_PyRuntime+283024>, frame=<optimized out>, throwflag=<optimized out>) at /usr/local/src/conda/python-3.13.5/Python/generated_cases.c.h:813
# #61 0x000056b17c2c1398 in pymain_run_module (modname=<optimized out>, set_argv0=1) at /usr/local/src/conda/python-3.13.5/Modules/main.c:349
# #62 0x000056b17c2c0566 in pymain_run_python (exitcode=0x7ffff555896c) at /usr/local/src/conda/python-3.13.5/Modules/main.c:690
# #63 Py_RunMain () at /usr/local/src/conda/python-3.13.5/Modules/main.c:775
# #64 0x000056b17c275d97 in Py_BytesMain (argc=<optimized out>, argv=<optimized out>) at /usr/local/src/conda/python-3.13.5/Modules/main.c:829
# #65 0x00007554c5629d90 in __libc_start_call_main (main=main
# entry=0x56b17c275ce0 <main>, argc=argc
# entry=5, argv=argv
# entry=0x7ffff5558bc8) at ../sysdeps/nptl/libc_start_call_main.h:58
# #66 0x00007554c5629e40 in __libc_start_main_impl (main=0x56b17c275ce0 <main>, argc=5, argv=0x7ffff5558bc8, init=<optimized out>, fini=<optimized out>, rtld_fini=<optimized out>, stack_end=0x7ffff5558bb8) at ../csu/libc-start.c:392
# #67 0x000056b17c27518e in _start ()
# ===========================================================
#
#
# The lines below might hint at the cause of the crash. If you see question
# marks as part of the stack trace, try to recompile with debugging information
# enabled and export CLING_DEBUG=1 environment variable before running.
# You may get help by asking at the ROOT forum https://root.cern/forum
# preferably using the command (.forum bug) in the ROOT prompt.
# Only if you are really convinced it is a bug in ROOT then please submit a
# report at https://root.cern/bugs or (preferably) using the command (.gh bug) in
# the ROOT prompt. Please post the ENTIRE stack trace
# from above as an attachment in addition to anything else
# that might help us fixing this issue.
# ===========================================================
# #7  0x000075547f76f76f in TInstrumentedIsAProxy<dataProducts::NaluPacketCollection>::operator()(void const*) () from /home/jack/cpp_projects/analysis_pipeline_project/apps/midas_file_unpacker_app/build/lib/libunpacker_data_products_nalu.so
# #8  0x00007554c009fa4f in Cppyy::GetActualClass(unsigned long, void*) () from /home/jack/miniconda3/envs/root_new/lib/python3.13/lib-dynload/../../libcppyy_backend.so
# #9  0x00007554799a9375 in CPyCppyy::BindCppObject(void*, unsigned long, unsigned int) () from /home/jack/miniconda3/envs/root_new/lib/python3.13/site-packages/libcppyy.so
# #10 0x000075547996f698 in CPyCppyy::CPPMethod::ExecuteFast(void*, long, CPyCppyy::CallContext*) [clone .isra.0] () from /home/jack/miniconda3/envs/root_new/lib/python3.13/site-packages/libcppyy.so
# #11 0x000075547996f848 in CPyCppyy::CPPMethod::ExecuteProtected(void*, long, CPyCppyy::CallContext*) () from /home/jack/miniconda3/envs/root_new/lib/python3.13/site-packages/libcppyy.so
# #12 0x000075547996f9d6 in CPyCppyy::CPPMethod::Execute(void*, long, CPyCppyy::CallContext*) () from /home/jack/miniconda3/envs/root_new/lib/python3.13/site-packages/libcppyy.so
# #13 0x0000755479965d30 in CPyCppyy::CPPFunction::Call(CPyCppyy::CPPInstance*&, _object* const*, unsigned long, _object*, CPyCppyy::CallContext*) () from /home/jack/miniconda3/envs/root_new/lib/python3.13/site-packages/libcppyy.so
# #14 0x0000755479977948 in CPyCppyy::(anonymous namespace)::mp_vectorcall(CPyCppyy::CPPOverload*, _object* const*, unsigned long, _object*) () from /home/jack/miniconda3/envs/root_new/lib/python3.13/site-packages/libcppyy.so
# #15 0x00007554799bd883 in CPyCppyy::tpp_vectorcall(CPyCppyy::TemplateProxy*, _object* const*, unsigned long, _object*) () from /home/jack/miniconda3/envs/root_new/lib/python3.13/site-packages/libcppyy.so
# #16 0x000056b17c1c70fe in _PyObject_VectorcallTstate (kwnames=<optimized out>, nargsf=<optimized out>, args=<optimized out>, callable=0x7554092b2700, tstate=0x56b17c5765b0 <_PyRuntime+283024>) at /usr/local/src/conda/python-3.13.5/Include/internal/pycore_call.h:168
# #17 PyObject_Vectorcall (callable=0x7554092b2700, args=<optimized out>, nargsf=<optimized out>, kwnames=<optimized out>) at /usr/local/src/conda/python-3.13.5/Objects/call.c:327
# #18 0x000056b17c0ba468 in _PyEval_EvalFrameDefault (tstate=0x56b17c5765b0 <_PyRuntime+283024>, frame=<optimized out>, throwflag=<optimized out>) at /usr/local/src/conda/python-3.13.5/Python/generated_cases.c.h:1843
# #19 0x000056b17c1c70fe in _PyObject_VectorcallTstate (kwnames=<optimized out>, nargsf=<optimized out>, args=<optimized out>, callable=0x7554c01884a0, tstate=0x56b17c5765b0 <_PyRuntime+283024>) at /usr/local/src/conda/python-3.13.5/Include/internal/pycore_call.h:168
# #20 PyObject_Vectorcall (callable=0x7554c01884a0, args=<optimized out>, nargsf=<optimized out>, kwnames=<optimized out>) at /usr/local/src/conda/python-3.13.5/Objects/call.c:327
# #21 0x000056b17c2d7685 in call_attribute (self=<optimized out>, attr=<optimized out>, name=0x75540ab195c0) at /usr/local/src/conda/python-3.13.5/Objects/typeobject.c:9600
# #22 0x000056b17c24ceef in _Py_slot_tp_getattr_hook (self=0x75540accaf50, name=0x75540ab195c0) at /usr/local/src/conda/python-3.13.5/Objects/typeobject.c:9650
# #23 0x000056b17c1c71b2 in PyObject_GetAttr (v=0x75540accaf50, name=0x75540ab195c0) at /usr/local/src/conda/python-3.13.5/Objects/object.c:1261
# #24 0x000056b17c0b1905 in _PyEval_EvalFrameDefault (tstate=0x56b17c5765b0 <_PyRuntime+283024>, frame=<optimized out>, throwflag=<optimized out>) at /usr/local/src/conda/python-3.13.5/Python/generated_cases.c.h:3770
# #25 0x000056b17c28a171 in PyEval_EvalCode (co=0x56b19ee42630, globals=<optimized out>, locals=0x7554c0260700) at /usr/local/src/conda/python-3.13.5/Python/ceval.c:604
# #26 0x000056b17c2a6699 in builtin_exec_impl (module=<optimized out>, closure=<optimized out>, locals=0x7554c0260700, globals=0x7554c0260700, source=0x56b19ee42630) at /usr/local/src/conda/python-3.13.5/Python/bltinmodule.c:1143
# #27 builtin_exec (module=<optimized out>, args=<optimized out>, nargs=<optimized out>, kwnames=<optimized out>) at /usr/local/src/conda/python-3.13.5/Python/clinic/bltinmodule.c.h:556
# #28 0x000056b17c0bd0f5 in _PyEval_EvalFrameDefault (tstate=0x56b17c5765b0 <_PyRuntime+283024>, frame=<optimized out>, throwflag=<optimized out>) at /usr/local/src/conda/python-3.13.5/Python/generated_cases.c.h:1217
# #29 0x000056b17c29e85a in _PyEval_EvalFrame (throwflag=0, frame=0x7554c048ca48, tstate=0x56b17c5765b0 <_PyRuntime+283024>) at /usr/local/src/conda/python-3.13.5/Include/internal/pycore_ceval.h:119
# #30 gen_send_ex2 (gen=0x7554c048ca00, arg=0x56b17c51ae90 <_Py_NoneStruct>, presult=0x7ffff5557d20, exc=0, closing=<optimized out>) at /usr/local/src/conda/python-3.13.5/Objects/genobject.c:229
# #31 0x000056b17c2f89f7 in gen_send_ex (gen=0x7554c048ca00, arg=<optimized out>, exc=<optimized out>, closing=<optimized out>) at /usr/local/src/conda/python-3.13.5/Objects/genobject.c:270
# #32 0x000056b17c0ba57f in _PyEval_EvalFrameDefault (tstate=0x56b17c5765b0 <_PyRuntime+283024>, frame=<optimized out>, throwflag=<optimized out>) at /usr/local/src/conda/python-3.13.5/Python/generated_cases.c.h:1796
# #33 0x000056b17c21b1d3 in _PyEval_EvalFrame (throwflag=0, frame=<optimized out>, tstate=0x56b17c5765b0 <_PyRuntime+283024>) at /usr/local/src/conda/python-3.13.5/Include/internal/pycore_ceval.h:119
# #34 _PyEval_Vector (kwnames=0x0, argcount=2, args=0x7554c0295800, locals=0x0, func=0x7554c366b6a0, tstate=0x56b17c5765b0 <_PyRuntime+283024>) at /usr/local/src/conda/python-3.13.5/Python/ceval.c:1816
# #35 _PyFunction_Vectorcall (kwnames=0x0, nargsf=2, stack=0x7554c0295800, func=0x7554c366b6a0) at /usr/local/src/conda/python-3.13.5/Objects/call.c:413
# #36 _PyObject_VectorcallTstate (kwnames=0x0, nargsf=2, args=0x7554c0295800, callable=0x7554c366b6a0, tstate=0x56b17c5765b0 <_PyRuntime+283024>) at /usr/local/src/conda/python-3.13.5/Include/internal/pycore_call.h:168
# #37 method_vectorcall (method=method
# entry=0x7554092c5c40, args=args
# entry=0x7554c0295808, nargsf=<optimized out>, kwnames=kwnames
# entry=0x75540b1ae340) at /usr/local/src/conda/python-3.13.5/Objects/classobject.c:62
# #38 0x000056b17c29674b in _PyVectorcall_Call (kwargs=<optimized out>, tuple=<optimized out>, callable=0x7554092c5c40, func=0x56b17c21ae00 <method_vectorcall>, tstate=0x56b17c5765b0 <_PyRuntime+283024>) at /usr/local/src/conda/python-3.13.5/Objects/call.c:285
# #39 _PyObject_Call (tstate=0x56b17c5765b0 <_PyRuntime+283024>, callable=0x7554092c5c40, args=<optimized out>, kwargs=<optimized out>) at /usr/local/src/conda/python-3.13.5/Objects/call.c:348
# #40 0x000056b17c0b3a1c in PyObject_Call (kwargs=0x7554092a5f40, args=0x7554c023c700, callable=0x7554092c5c40) at /usr/local/src/conda/python-3.13.5/Objects/call.c:373
# #41 PyCFunction_Call (kwargs=0x7554092a5f40, args=0x7554c023c700, callable=0x7554092c5c40) at /usr/local/src/conda/python-3.13.5/Objects/call.c:381
# #42 _PyEval_EvalFrameDefault (tstate=0x56b17c5765b0 <_PyRuntime+283024>, frame=<optimized out>, throwflag=<optimized out>) at /usr/local/src/conda/python-3.13.5/Python/generated_cases.c.h:1355
# #43 0x000056b17c29e85a in _PyEval_EvalFrame (throwflag=0, frame=0x7554c02db898, tstate=0x56b17c5765b0 <_PyRuntime+283024>) at /usr/local/src/conda/python-3.13.5/Include/internal/pycore_ceval.h:119
# #44 gen_send_ex2 (gen=0x7554c02db850, arg=0x56b17c51ae90 <_Py_NoneStruct>, presult=0x7ffff5558268, exc=0, closing=<optimized out>) at /usr/local/src/conda/python-3.13.5/Objects/genobject.c:229
# #45 0x00007554c42c569d in task_step_impl (state=state
# entry=0x7554c4da3cb0, task=task
# entry=0x7554c030e830, exc=exc
# entry=0x0) at /usr/local/src/conda/python-3.13.5/Modules/_asynciomodule.c:2782
# #46 0x00007554c42c6d6b in task_step (state=0x7554c4da3cb0, task=0x7554c030e830, exc=0x0) at /usr/local/src/conda/python-3.13.5/Modules/_asynciomodule.c:3101
# #47 0x000056b17c1e6bb8 in cfunction_vectorcall_O (func=0x7554c264d9e0, args=0x7554c026b720, nargsf=<optimized out>, kwnames=<optimized out>) at /usr/local/src/conda/python-3.13.5/Include/cpython/methodobject.h:50
# #48 0x000056b17c32834c in _PyObject_VectorcallTstate (tstate=0x56b17c5765b0 <_PyRuntime+283024>, callable=0x7554c264d9e0, args=<optimized out>, nargsf=<optimized out>, kwnames=<optimized out>) at /usr/local/src/conda/python-3.13.5/Include/internal/pycore_call.h:168
# #49 0x000056b17c180106 in context_run (self=0x7554c0285f00, args=0x7554c026b718, nargs=2, kwnames=0x0) at /usr/local/src/conda/python-3.13.5/Python/context.c:664
# #50 0x000056b17c1e051b in cfunction_vectorcall_FASTCALL_KEYWORDS (func=<optimized out>, args=0x7554c026b718, nargsf=<optimized out>, kwnames=<optimized out>) at /usr/local/src/conda/python-3.13.5/Objects/methodobject.c:441
# #51 0x000056b17c0b3a1c in PyObject_Call (kwargs=0x0, args=0x7554c026b700, callable=0x7554c0541580) at /usr/local/src/conda/python-3.13.5/Objects/call.c:373
# #52 PyCFunction_Call (kwargs=0x0, args=0x7554c026b700, callable=0x7554c0541580) at /usr/local/src/conda/python-3.13.5/Objects/call.c:381
# #53 _PyEval_EvalFrameDefault (tstate=0x56b17c5765b0 <_PyRuntime+283024>, frame=<optimized out>, throwflag=<optimized out>) at /usr/local/src/conda/python-3.13.5/Python/generated_cases.c.h:1355
# #54 0x000056b17c28a171 in PyEval_EvalCode (co=0x7554c5949e90, globals=<optimized out>, locals=0x7554c5540180) at /usr/local/src/conda/python-3.13.5/Python/ceval.c:604
# #55 0x000056b17c2a6699 in builtin_exec_impl (module=<optimized out>, closure=<optimized out>, locals=0x7554c5540180, globals=0x7554c5540180, source=0x7554c5949e90) at /usr/local/src/conda/python-3.13.5/Python/bltinmodule.c:1143
# #56 builtin_exec (module=<optimized out>, args=<optimized out>, nargs=<optimized out>, kwnames=<optimized out>) at /usr/local/src/conda/python-3.13.5/Python/clinic/bltinmodule.c.h:556
# #57 0x000056b17c1e051b in cfunction_vectorcall_FASTCALL_KEYWORDS (func=<optimized out>, args=0x7554c5aeb180, nargsf=<optimized out>, kwnames=<optimized out>) at /usr/local/src/conda/python-3.13.5/Objects/methodobject.c:441
# #58 0x000056b17c1c70fe in _PyObject_VectorcallTstate (kwnames=<optimized out>, nargsf=<optimized out>, args=<optimized out>, callable=0x7554c593a200, tstate=0x56b17c5765b0 <_PyRuntime+283024>) at /usr/local/src/conda/python-3.13.5/Include/internal/pycore_call.h:168
# #59 PyObject_Vectorcall (callable=0x7554c593a200, args=<optimized out>, nargsf=<optimized out>, kwnames=<optimized out>) at /usr/local/src/conda/python-3.13.5/Objects/call.c:327
# #60 0x000056b17c0b3e73 in _PyEval_EvalFrameDefault (tstate=0x56b17c5765b0 <_PyRuntime+283024>, frame=<optimized out>, throwflag=<optimized out>) at /usr/local/src/conda/python-3.13.5/Python/generated_cases.c.h:813
# #61 0x000056b17c2c1398 in pymain_run_module (modname=<optimized out>, set_argv0=1) at /usr/local/src/conda/python-3.13.5/Modules/main.c:349
# #62 0x000056b17c2c0566 in pymain_run_python (exitcode=0x7ffff555896c) at /usr/local/src/conda/python-3.13.5/Modules/main.c:690
# #63 Py_RunMain () at /usr/local/src/conda/python-3.13.5/Modules/main.c:775
# #64 0x000056b17c275d97 in Py_BytesMain (argc=<optimized out>, argv=<optimized out>) at /usr/local/src/conda/python-3.13.5/Modules/main.c:829
# #65 0x00007554c5629d90 in __libc_start_call_main (main=main
# entry=0x56b17c275ce0 <main>, argc=argc
# entry=5, argv=argv
# entry=0x7ffff5558bc8) at ../sysdeps/nptl/libc_start_call_main.h:58
# #66 0x00007554c5629e40 in __libc_start_main_impl (main=0x56b17c275ce0 <main>, argc=5, argv=0x7ffff5558bc8, init=<optimized out>, fini=<optimized out>, rtld_fini=<optimized out>, stack_end=0x7ffff5558bb8) at ../csu/libc-start.c:392
# #67 0x000056b17c27518e in _start ()
# ===========================================================

# %%
# Accumulate sample/value pairs per channel
channel_samples = defaultdict(list)
channel_values = defaultdict(list)

# Also store a few example waveforms per channel
example_waveforms = defaultdict(list)
max_examples = 3  # how many example pulses per channel

for evt in tree:
    for wf in evt.nalu_event.waveforms.waveforms:
        ch = int(wf.channel_num)
        trace = np.array([wf.trace[k] for k in range(len(wf.trace))], dtype=np.int16)

        # Fill 2D hist data
        channel_samples[ch].extend(range(len(trace)))
        channel_values[ch].extend(trace)

        # Save a few examples
        if len(example_waveforms[ch]) < max_examples:
            example_waveforms[ch].append(trace)

f.Close()

# --- Plot 2D hists ---
n_channels = len(channel_samples)
fig, axes = plt.subplots(1, n_channels, figsize=(6*n_channels, 5), sharey=True)

if n_channels == 1:
    axes = [axes]

for ax, ch in zip(axes, sorted(channel_samples.keys())):
    x = np.array(channel_samples[ch])
    y = np.array(channel_values[ch])
    
    hb = ax.hist2d(x, y, bins=[200, 200], cmap="viridis", cmin=1)
    fig.colorbar(hb[3], ax=ax, label="Counts")
    
    # Draw vertical lines every 32 samples
    xmax = x.max()
    for xline in range(0, xmax+1, 32):
        ax.axvline(xline, color="red", linestyle="--", alpha=0.4, linewidth=1)
    
    ax.set_title(f"Channel {ch} — 2D Density")
    ax.set_xlabel("Sample Index")
    ax.set_ylabel("ADC Value")

plt.tight_layout()
plt.show()

# --- Plot example pulses ---
fig, axes = plt.subplots(n_channels, 1, figsize=(8, 3*n_channels), sharex=True)

if n_channels == 1:
    axes = [axes]

for ax, ch in zip(axes, sorted(example_waveforms.keys())):
    max_len = max(len(trace) for trace in example_waveforms[ch])
    for i, trace in enumerate(example_waveforms[ch]):
        ax.plot(trace, label=f"Example {i+1}", alpha=0.7)
    
    # Draw vertical lines every 32 samples
    for xline in range(0, max_len, 32):
        ax.axvline(xline, color="red", linestyle="--", alpha=0.4, linewidth=1)
    
    ax.set_title(f"Channel {ch} — Example Pulses")
    ax.set_ylabel("ADC Value")
    ax.legend()

axes[-1].set_xlabel("Sample Index")
plt.tight_layout()
plt.show()
